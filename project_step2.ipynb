# %%
import pandas as pd
from sklearn.feature_selection import VarianceThreshold
import numpy as np
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeClassifier

# %%
data1 = pd.read_csv("covtype1.csv")
data2 = pd.read_csv("covertype 2.csv")
dataset = data1.append(data2) 

export_csv = dataset.to_csv (r'bigdataset.csv', index = None, header=True)
final_set = pd.read_csv("bigdataset.csv")
# Out:
# 256804
# 324208
# 581012

# %%
dataset.describe(include='all').transpose()
# Out:
#                                        count         mean          std  \
# Elevation                           581012.0  2959.365301   279.984734
# Aspect                              581012.0   155.656807   111.913721
# Slope                               581011.0    14.103712     7.488245
# Horizontal_Distance_To_Hydrology    581012.0   269.428217   212.549356
# Vertical_Distance_To_Hydrology      581012.0    46.418855    58.295232
# Horizontal_Distance_To_Roadways     581012.0  2350.146611  1559.254870
# Hillshade_9am                       581012.0   212.146049    26.769889
# Hillshade_Noon                      581011.0   223.318701    19.768711
# Hillshade_3pm                       581012.0   142.528263    38.274529
# Horizontal_Distance_To_Fire_Points  581012.0  1980.291226  1324.195210
# Wilderness_Area1                    581012.0     0.448865     0.497379
# Wilderness_Area2                    581012.0     0.051434     0.220882
# ...

# %%
dataset.Elevation
# Out:
# 0         2596
# 1         2590
# 2         2804
# 3         2785
# 4         2595
# 5         2579
# 6         2606
# 7         2605
# 8         2617
# 9         2612
# 10        2612
# 11        2886
# 12        2742
# 13        2609
# 14        2503
# 15        2495
# 16        2610
# 17        2517
# 18        2504
# 19        2503
# 20        2501
# 21        2880
# 22        2768
# 23        2511
# 24        2507
# 25        2492
# 26        2489
# 27        2962
# 28        2811
# 29        2739
#           ...
# 324178    2431
# 324179    2436
# 324180    2441
# 324181    2442
# 324182    2444
# 324183    2450
# 324184    2455
# 324185    2455
# 324186    2455
# 324187    2445
# 324188    2441
# 324189    2440
# 324190    2437
# 324191    2437
# 324192    2435
# 324193    2433
# 324194    2429
# 324195    2426
# 324196    2423
# 324197    2421
# 324198    2419
# 324199    2415
# 324200    2410
# 324201    2405
# 324202    2401
# 324203    2396
# 324204    2391
# ...

# %%
g = dataset2.groupby('class')
g.apply(lambda x: x.sample(g.size().min()).reset_index(drop=True)

# %%
print(dataset.Elevation)
print(dataset.Aspect)
# Out:
# 0         2596
# 1         2590
# 2         2804
# 3         2785
# 4         2595
# 5         2579
# 6         2606
# 7         2605
# 8         2617
# 9         2612
# 10        2612
# 11        2886
# 12        2742
# 13        2609
# 14        2503
# 15        2495
# 16        2610
# 17        2517
# 18        2504
# 19        2503
# 20        2501
# 21        2880
# 22        2768
# 23        2511
# 24        2507
# 25        2492
# 26        2489
# 27        2962
# 28        2811
# 29        2739
#           ...
# 324178    2431
# 324179    2436
# 324180    2441
# 324181    2442
# 324182    2444
# 324183    2450
# 324184    2455
# 324185    2455
# 324186    2455
# 324187    2445
# 324188    2441
# 324189    2440
# 324190    2437
# 324191    2437
# 324192    2435
# 324193    2433
# 324194    2429
# 324195    2426
# 324196    2423
# 324197    2421
# 324198    2419
# 324199    2415
# 324200    2410
# 324201    2405
# 324202    2401
# 324203    2396
# 324204    2391
# ...

# %%
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
data3 = pd.read_csv("bigdataset.csv")
data3.Elevation
# Out:
# 0         2596
# 1         2590
# 2         2804
# 3         2785
# 4         2595
# 5         2579
# 6         2606
# 7         2605
# 8         2617
# 9         2612
# 10        2612
# 11        2886
# 12        2742
# 13        2609
# 14        2503
# 15        2495
# 16        2610
# 17        2517
# 18        2504
# 19        2503
# 20        2501
# 21        2880
# 22        2768
# 23        2511
# 24        2507
# 25        2492
# 26        2489
# 27        2962
# 28        2811
# 29        2739
#           ...
# 580982    2431
# 580983    2436
# 580984    2441
# 580985    2442
# 580986    2444
# 580987    2450
# 580988    2455
# 580989    2455
# 580990    2455
# 580991    2445
# 580992    2441
# 580993    2440
# 580994    2437
# 580995    2437
# 580996    2435
# 580997    2433
# 580998    2429
# 580999    2426
# 581000    2423
# 581001    2421
# 581002    2419
# 581003    2415
# 581004    2410
# 581005    2405
# 581006    2401
# 581007    2396
# 581008    2391
# ...

# %%
list1 = []
list2 = []
for x in data3.Elevation:
    list1 += [x]
for x in data3.Aspect:
    list2 += [x]
print(list1[-20:-1])
print(list2[-20:-1])
# Out:
# [2441, 2440, 2437, 2437, 2435, 2433, 2429, 2426, 2423, 2421, 2419, 2415, 2410, 2405, 2401, 2396, 2391, 2386, 2384]
# [173, 173, 170, 174, 171, 168, 166, 168, 169, 172, 168, 161, 158, 159, 157, 153, 152, 159, 170]
